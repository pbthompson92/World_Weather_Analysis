# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# %%
# create a set of random lats and lngs combos
lats = np.random.uniform(-90,90,size =1500)
lngs = np.random.uniform(-180,180,size = 1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add lats and longs to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding cities
cities = []

# id the nearest city for each lat and lngs combination 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if city is uniqe add to cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 652

# %%
# import API key
from config import weather_api_key

# %%
# create URL from Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an empty list to hold the weather date 
city_data = []

# print the beginning of the logging
print('Beginning Data Retrieval       ')
print('-------------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all cities in the list 
for i, city in enumerate(cities):
    
    # group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create endpoint URL with each city 
    city_url = url + '&q=' + city.replace(' ', '+')
    
    #log the URl, record and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # add 1 to record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | kavaratti
# Processing Record 3 of Set 1 | kirkwood
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | zutendaal
# Processing Record 13 of Set 1 | mbandaka
# Processing Record 14 of Set 1 | amga
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | litovko
# Processing Record 17 of Set 1 | sesheke
# Processing Record 18 of Set 1 | kerema
# Processing Record 19 of Set 1 | anuchino
# Processing Record 20 of Set 1 | ndende
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | tanout
# Processing Record 24 of Set 1 | vanimo
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | yumen
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | portage
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 1 | siderno
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | kinablangan
# Processing Record 41 of Set 1 | hamilton
# Processing Record 42 of Set 1 | mount gambier
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | uthal
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | jacareacanga
# Processing Record 47 of Set 1 | pecos
# Processing Record 48 of Set 1 | shimoda
# Processing Record 49 of Set 1 | ascension
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | daru
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 2 | olafsvik
# Processing Record 8 of Set 2 | ekhabi
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | srednekolymsk
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | samarai
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | roald
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | mala tokmachka
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 2 | kharp
# Processing Record 24 of Set 2 | las palmas
# Processing Record 25 of Set 2 | mgandu
# Processing Record 26 of Set 2 | vuktyl
# Processing Record 27 of Set 2 | thongwa
# Processing Record 28 of Set 2 | severo-kurilsk
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | waingapu
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | lincoln
# Processing Record 33 of Set 2 | northam
# Processing Record 34 of Set 2 | tura
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | macamic
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | salinas
# Processing Record 41 of Set 2 | shu
# Processing Record 42 of Set 2 | punta alta
# Processing Record 43 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | port augusta
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | mangaratiba
# Processing Record 48 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 2 | pontes e lacerda
# Processing Record 50 of Set 2 | ilulissat
# Processing Record 1 of Set 3 | paamiut
# Processing Record 2 of Set 3 | gambela
# Processing Record 3 of Set 3 | deputatskiy
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | tenenkou
# Processing Record 6 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | vostok
# Processing Record 9 of Set 3 | kathu
# Processing Record 10 of Set 3 | gravdal
# Processing Record 11 of Set 3 | matagami
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | vao
# Processing Record 14 of Set 3 | kakching
# Processing Record 15 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 3 | cayenne
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | saravan
# Processing Record 21 of Set 3 | pangnirtung
# Processing Record 22 of Set 3 | port-cartier
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | luganville
# Processing Record 25 of Set 3 | arlit
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | praia
# Processing Record 28 of Set 3 | archdale
# Processing Record 29 of Set 3 | perth
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | beloha
# Processing Record 32 of Set 3 | lloret de mar
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | hami
# Processing Record 35 of Set 3 | turayf
# Processing Record 36 of Set 3 | aksu
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | pozo colorado
# Processing Record 39 of Set 3 | pachino
# Processing Record 40 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 3 | north bend
# Processing Record 42 of Set 3 | port shepstone
# Processing Record 43 of Set 3 | baykit
# Processing Record 44 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 3 | gien
# Processing Record 46 of Set 3 | yulara
# Processing Record 47 of Set 3 | cozumel
# Processing Record 48 of Set 3 | biak
# Processing Record 49 of Set 3 | westport
# Processing Record 50 of Set 3 | nisia floresta
# Processing Record 1 of Set 4 | buraydah
# Processing Record 2 of Set 4 | kabare
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | mount isa
# Processing Record 5 of Set 4 | teavaro
# Processing Record 6 of Set 4 | madimba
# Processing Record 7 of Set 4 | grand gaube
# Processing Record 8 of Set 4 | chifeng
# Processing Record 9 of Set 4 | khanpur
# Processing Record 10 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 4 | krasnoselkup
# Processing Record 12 of Set 4 | hokitika
# Processing Record 13 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 4 | udachnyy
# Processing Record 15 of Set 4 | dawei
# Processing Record 16 of Set 4 | muli
# Processing Record 17 of Set 4 | orumiyeh
# Processing Record 18 of Set 4 | boueni
# Processing Record 19 of Set 4 | pevek
# Processing Record 20 of Set 4 | caucaia
# Processing Record 21 of Set 4 | morros
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | ust-maya
# Processing Record 24 of Set 4 | kytlym
# City not found. Skipping...
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | camacha
# Processing Record 27 of Set 4 | finnsnes
# Processing Record 28 of Set 4 | port moresby
# Processing Record 29 of Set 4 | sitka
# Processing Record 30 of Set 4 | santa fe
# Processing Record 31 of Set 4 | nambucca heads
# Processing Record 32 of Set 4 | kichera
# Processing Record 33 of Set 4 | port hedland
# Processing Record 34 of Set 4 | ulladulla
# Processing Record 35 of Set 4 | muravlenko
# Processing Record 36 of Set 4 | rawson
# Processing Record 37 of Set 4 | pangody
# Processing Record 38 of Set 4 | dilbeek
# Processing Record 39 of Set 4 | acarau
# Processing Record 40 of Set 4 | nakusp
# Processing Record 41 of Set 4 | encarnacion
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | yar-sale
# Processing Record 44 of Set 4 | maraa
# Processing Record 45 of Set 4 | kenai
# Processing Record 46 of Set 4 | lerwick
# Processing Record 47 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 48 of Set 4 | itaituba
# Processing Record 49 of Set 4 | nome
# Processing Record 50 of Set 4 | andros town
# Processing Record 1 of Set 5 | lakatoro
# Processing Record 2 of Set 5 | karratha
# Processing Record 3 of Set 5 | bonavista
# Processing Record 4 of Set 5 | galveston
# Processing Record 5 of Set 5 | maniitsoq
# Processing Record 6 of Set 5 | terra santa
# Processing Record 7 of Set 5 | terekli-mekteb
# Processing Record 8 of Set 5 | awjilah
# Processing Record 9 of Set 5 | kodiak
# Processing Record 10 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 5 | vaini
# Processing Record 12 of Set 5 | bouar
# Processing Record 13 of Set 5 | sabang
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | kutum
# Processing Record 17 of Set 5 | maku
# Processing Record 18 of Set 5 | erenhot
# Processing Record 19 of Set 5 | santa maria
# Processing Record 20 of Set 5 | caravelas
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | balaipungut
# Processing Record 23 of Set 5 | darnah
# Processing Record 24 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | iquitos
# Processing Record 27 of Set 5 | pechenga
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | horta
# Processing Record 30 of Set 5 | mayo
# Processing Record 31 of Set 5 | kuytun
# Processing Record 32 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 5 | talnakh
# Processing Record 34 of Set 5 | inirida
# Processing Record 35 of Set 5 | san patricio
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | beyneu
# Processing Record 38 of Set 5 | springdale
# Processing Record 39 of Set 5 | meulaboh
# Processing Record 40 of Set 5 | cabedelo
# Processing Record 41 of Set 5 | carnarvon
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | majene
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | erzin
# Processing Record 46 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 5 | isangel
# Processing Record 48 of Set 5 | natal
# Processing Record 49 of Set 5 | tena
# Processing Record 50 of Set 5 | warrington
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | poum
# Processing Record 3 of Set 6 | jiuquan
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | college
# Processing Record 6 of Set 6 | nelson bay
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | souillac
# Processing Record 9 of Set 6 | dali
# Processing Record 10 of Set 6 | chaupal
# Processing Record 11 of Set 6 | galdar
# Processing Record 12 of Set 6 | colorado springs
# Processing Record 13 of Set 6 | yangambi
# Processing Record 14 of Set 6 | havre-saint-pierre
# Processing Record 15 of Set 6 | port lincoln
# Processing Record 16 of Set 6 | sibu
# Processing Record 17 of Set 6 | bireun
# Processing Record 18 of Set 6 | rock springs
# Processing Record 19 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 6 | poso
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | avarua
# Processing Record 24 of Set 6 | orsk
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | phrai bung
# City not found. Skipping...
# Processing Record 27 of Set 6 | kirkuk
# Processing Record 28 of Set 6 | murray bridge
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | acapulco
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | niquelandia
# Processing Record 33 of Set 6 | tazovskiy
# Processing Record 34 of Set 6 | ribeira grande
# Processing Record 35 of Set 6 | tiksi
# Processing Record 36 of Set 6 | bukit bakri
# City not found. Skipping...
# Processing Record 37 of Set 6 | kudeyevskiy
# Processing Record 38 of Set 6 | itarema
# Processing Record 39 of Set 6 | george town
# Processing Record 40 of Set 6 | lashio
# Processing Record 41 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 42 of Set 6 | mehamn
# Processing Record 43 of Set 6 | kyren
# Processing Record 44 of Set 6 | alofi
# Processing Record 45 of Set 6 | lebu
# Processing Record 46 of Set 6 | new norfolk
# Processing Record 47 of Set 6 | posse
# Processing Record 48 of Set 6 | geraldton
# Processing Record 49 of Set 6 | komsomolskiy
# Processing Record 50 of Set 6 | port elizabeth
# Processing Record 1 of Set 7 | umm kaddadah
# Processing Record 2 of Set 7 | burica
# City not found. Skipping...
# Processing Record 3 of Set 7 | shubarshi
# Processing Record 4 of Set 7 | korhogo
# Processing Record 5 of Set 7 | halifax
# Processing Record 6 of Set 7 | timra
# Processing Record 7 of Set 7 | denpasar
# Processing Record 8 of Set 7 | portland
# Processing Record 9 of Set 7 | bilma
# Processing Record 10 of Set 7 | teya
# Processing Record 11 of Set 7 | garoua
# Processing Record 12 of Set 7 | longyearbyen
# Processing Record 13 of Set 7 | saint-joseph
# Processing Record 14 of Set 7 | esmeralda
# Processing Record 15 of Set 7 | lorengau
# Processing Record 16 of Set 7 | mahibadhoo
# Processing Record 17 of Set 7 | rogaska slatina
# Processing Record 18 of Set 7 | upernavik
# Processing Record 19 of Set 7 | leh
# Processing Record 20 of Set 7 | senno
# Processing Record 21 of Set 7 | lundazi
# Processing Record 22 of Set 7 | cockburn town
# Processing Record 23 of Set 7 | bougouni
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | cabo san lucas
# Processing Record 26 of Set 7 | tezu
# Processing Record 27 of Set 7 | port hawkesbury
# Processing Record 28 of Set 7 | itaqui
# Processing Record 29 of Set 7 | kulti
# Processing Record 30 of Set 7 | pau
# Processing Record 31 of Set 7 | bucerias
# Processing Record 32 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 33 of Set 7 | nerchinskiy zavod
# Processing Record 34 of Set 7 | guerrero negro
# Processing Record 35 of Set 7 | faanui
# Processing Record 36 of Set 7 | bandipur
# Processing Record 37 of Set 7 | nishihara
# Processing Record 38 of Set 7 | castro
# Processing Record 39 of Set 7 | haapiti
# Processing Record 40 of Set 7 | hirado
# Processing Record 41 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 7 | waipawa
# Processing Record 43 of Set 7 | baktaloranthaza
# Processing Record 44 of Set 7 | asau
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | angoche
# Processing Record 47 of Set 7 | batticaloa
# Processing Record 48 of Set 7 | turriff
# Processing Record 49 of Set 7 | neiafu
# Processing Record 50 of Set 7 | antofagasta
# Processing Record 1 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 2 of Set 8 | kirakira
# Processing Record 3 of Set 8 | bentiu
# Processing Record 4 of Set 8 | qinzhou
# Processing Record 5 of Set 8 | gushikawa
# Processing Record 6 of Set 8 | pisco
# Processing Record 7 of Set 8 | zurrieq
# Processing Record 8 of Set 8 | jibuti
# Processing Record 9 of Set 8 | swan river
# Processing Record 10 of Set 8 | beringovskiy
# Processing Record 11 of Set 8 | tabuk
# Processing Record 12 of Set 8 | asosa
# Processing Record 13 of Set 8 | avare
# Processing Record 14 of Set 8 | saeby
# Processing Record 15 of Set 8 | coihaique
# Processing Record 16 of Set 8 | kurumkan
# Processing Record 17 of Set 8 | umtata
# Processing Record 18 of Set 8 | kavieng
# Processing Record 19 of Set 8 | mandalgovi
# Processing Record 20 of Set 8 | luwuk
# Processing Record 21 of Set 8 | fenoarivo
# Processing Record 22 of Set 8 | jutai
# Processing Record 23 of Set 8 | vestmannaeyjar
# Processing Record 24 of Set 8 | cowra
# Processing Record 25 of Set 8 | urumqi
# Processing Record 26 of Set 8 | shingu
# Processing Record 27 of Set 8 | xiashi
# Processing Record 28 of Set 8 | hervey bay
# Processing Record 29 of Set 8 | buchanan
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | gerash
# Processing Record 32 of Set 8 | yichang
# Processing Record 33 of Set 8 | airai
# Processing Record 34 of Set 8 | komsomolets
# Processing Record 35 of Set 8 | chiang klang
# Processing Record 36 of Set 8 | shakiso
# Processing Record 37 of Set 8 | sorland
# Processing Record 38 of Set 8 | mercedes
# Processing Record 39 of Set 8 | lewistown
# Processing Record 40 of Set 8 | seoul
# Processing Record 41 of Set 8 | coquimbo
# City not found. Skipping...
# Processing Record 42 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 8 | zaozerne
# Processing Record 44 of Set 8 | mangit
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | paredon
# Processing Record 47 of Set 8 | saint-augustin
# Processing Record 48 of Set 8 | belmonte
# Processing Record 49 of Set 8 | maramba
# Processing Record 50 of Set 8 | rockport
# Processing Record 1 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 9 | viedma
# Processing Record 3 of Set 9 | sao filipe
# Processing Record 4 of Set 9 | santa vitoria do palmar
# Processing Record 5 of Set 9 | narsaq
# Processing Record 6 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 9 | liberal
# Processing Record 8 of Set 9 | plouzane
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | boa vista
# Processing Record 11 of Set 9 | ormstown
# Processing Record 12 of Set 9 | belaya gora
# Processing Record 13 of Set 9 | valenca
# Processing Record 14 of Set 9 | sovetskiy
# Processing Record 15 of Set 9 | polyarnyy
# Processing Record 16 of Set 9 | wahiawa
# Processing Record 17 of Set 9 | taoudenni
# Processing Record 18 of Set 9 | nyurba
# Processing Record 19 of Set 9 | novomykolayivka
# Processing Record 20 of Set 9 | badulla
# Processing Record 21 of Set 9 | porbandar
# Processing Record 22 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 23 of Set 9 | ibirama
# Processing Record 24 of Set 9 | mirnyy
# Processing Record 25 of Set 9 | fortuna
# Processing Record 26 of Set 9 | henderson
# Processing Record 27 of Set 9 | sidi ali
# Processing Record 28 of Set 9 | gamba
# Processing Record 29 of Set 9 | tagusao
# Processing Record 30 of Set 9 | sao gabriel da cachoeira
# Processing Record 31 of Set 9 | evensk
# Processing Record 32 of Set 9 | scarborough
# Processing Record 33 of Set 9 | rajauri
# Processing Record 34 of Set 9 | lompoc
# Processing Record 35 of Set 9 | orbetello
# Processing Record 36 of Set 9 | kloulklubed
# Processing Record 37 of Set 9 | bloomingdale
# Processing Record 38 of Set 9 | la ronge
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | victoria
# Processing Record 41 of Set 9 | noumea
# Processing Record 42 of Set 9 | kiama
# Processing Record 43 of Set 9 | beitbridge
# Processing Record 44 of Set 9 | burnie
# Processing Record 45 of Set 9 | kormista
# Processing Record 46 of Set 9 | antalaha
# Processing Record 47 of Set 9 | norman wells
# Processing Record 48 of Set 9 | adrar
# Processing Record 49 of Set 9 | nemuro
# Processing Record 50 of Set 9 | hosanagara
# Processing Record 1 of Set 10 | genhe
# Processing Record 2 of Set 10 | zhigansk
# Processing Record 3 of Set 10 | quelimane
# Processing Record 4 of Set 10 | mzimba
# Processing Record 5 of Set 10 | dongsheng
# Processing Record 6 of Set 10 | tananger
# Processing Record 7 of Set 10 | toowoomba
# Processing Record 8 of Set 10 | roebourne
# Processing Record 9 of Set 10 | ponta delgada
# Processing Record 10 of Set 10 | hammerfest
# Processing Record 11 of Set 10 | kashi
# Processing Record 12 of Set 10 | mogadishu
# Processing Record 13 of Set 10 | lodwar
# Processing Record 14 of Set 10 | salas
# Processing Record 15 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 10 | bollnas
# Processing Record 17 of Set 10 | kaiyuan
# Processing Record 18 of Set 10 | uddevalla
# Processing Record 19 of Set 10 | medicine hat
# Processing Record 20 of Set 10 | saint george
# Processing Record 21 of Set 10 | copiapo
# Processing Record 22 of Set 10 | olavarria
# Processing Record 23 of Set 10 | quatre cocos
# Processing Record 24 of Set 10 | sao pedro
# Processing Record 25 of Set 10 | bowen
# Processing Record 26 of Set 10 | kupang
# Processing Record 27 of Set 10 | hasaki
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | husavik
# Processing Record 30 of Set 10 | flinders
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | mana
# Processing Record 33 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 34 of Set 10 | nouadhibou
# Processing Record 35 of Set 10 | nasirabad
# Processing Record 36 of Set 10 | chapais
# Processing Record 37 of Set 10 | carroll
# Processing Record 38 of Set 10 | chegdomyn
# Processing Record 39 of Set 10 | dzhebariki-khaya
# Processing Record 40 of Set 10 | fairlie
# Processing Record 41 of Set 10 | numan
# Processing Record 42 of Set 10 | hirara
# Processing Record 43 of Set 10 | mwanza
# Processing Record 44 of Set 10 | klaksvik
# Processing Record 45 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 10 | union
# Processing Record 48 of Set 10 | bol
# Processing Record 49 of Set 10 | avera
# Processing Record 50 of Set 10 | bielsk podlaski
# Processing Record 1 of Set 11 | sumbe
# Processing Record 2 of Set 11 | puteyets
# Processing Record 3 of Set 11 | aloleng
# Processing Record 4 of Set 11 | ambilobe
# Processing Record 5 of Set 11 | berlevag
# Processing Record 6 of Set 11 | brigantine
# Processing Record 7 of Set 11 | lano
# Processing Record 8 of Set 11 | hambantota
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | camana
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | gillette
# Processing Record 13 of Set 11 | bell ville
# Processing Record 14 of Set 11 | haines junction
# Processing Record 15 of Set 11 | ahipara
# Processing Record 16 of Set 11 | nassau
# Processing Record 17 of Set 11 | puerto leguizamo
# Processing Record 18 of Set 11 | murupara
# Processing Record 19 of Set 11 | gizo
# Processing Record 20 of Set 11 | dalgopol
# Processing Record 21 of Set 11 | elizabeth city
# Processing Record 22 of Set 11 | bereda
# Processing Record 23 of Set 11 | stryn
# Processing Record 24 of Set 11 | bambous virieux
# Processing Record 25 of Set 11 | ghorawal
# Processing Record 26 of Set 11 | zhangzhou
# Processing Record 27 of Set 11 | opuwo
# Processing Record 28 of Set 11 | piripiri
# Processing Record 29 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 11 | woodward
# Processing Record 31 of Set 11 | gigmoto
# Processing Record 32 of Set 11 | worthington
# Processing Record 33 of Set 11 | hanstholm
# Processing Record 34 of Set 11 | ugoofaaru
# Processing Record 35 of Set 11 | palauig
# Processing Record 36 of Set 11 | soyo
# Processing Record 37 of Set 11 | sistranda
# Processing Record 38 of Set 11 | lake charles
# Processing Record 39 of Set 11 | tongren
# Processing Record 40 of Set 11 | micheweni
# Processing Record 41 of Set 11 | sandpoint
# Processing Record 42 of Set 11 | magadan
# Processing Record 43 of Set 11 | aksum
# Processing Record 44 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 45 of Set 11 | goundam
# Processing Record 46 of Set 11 | zachary
# Processing Record 47 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 11 | dafeng
# Processing Record 49 of Set 11 | kyra
# Processing Record 50 of Set 11 | najran
# Processing Record 1 of Set 12 | pionerskiy
# Processing Record 2 of Set 12 | yangshe
# Processing Record 3 of Set 12 | karatau
# Processing Record 4 of Set 12 | corinto
# Processing Record 5 of Set 12 | mahanoro
# Processing Record 6 of Set 12 | buckeye
# Processing Record 7 of Set 12 | roma
# Processing Record 8 of Set 12 | christchurch
# Processing Record 9 of Set 12 | touros
# Processing Record 10 of Set 12 | maragogi
# Processing Record 11 of Set 12 | beterou
# Processing Record 12 of Set 12 | rio gallegos
# Processing Record 13 of Set 12 | maralal
# Processing Record 14 of Set 12 | tarauaca
# Processing Record 15 of Set 12 | cassilandia
# Processing Record 16 of Set 12 | diedorf
# Processing Record 17 of Set 12 | langelsheim
# Processing Record 18 of Set 12 | khanu woralaksaburi
# Processing Record 19 of Set 12 | cadillac
# Processing Record 20 of Set 12 | aklavik
# Processing Record 21 of Set 12 | monte patria
# Processing Record 22 of Set 12 | bubaque
# Processing Record 23 of Set 12 | tygda
# Processing Record 24 of Set 12 | syracuse
# Processing Record 25 of Set 12 | astoria
# Processing Record 26 of Set 12 | port hardy
# Processing Record 27 of Set 12 | nanakuli
# Processing Record 28 of Set 12 | qazanbulaq
# Processing Record 29 of Set 12 | slave lake
# Processing Record 30 of Set 12 | kalmunai
# Processing Record 31 of Set 12 | kayerkan
# Processing Record 32 of Set 12 | panaba
# Processing Record 33 of Set 12 | great yarmouth
# Processing Record 34 of Set 12 | nioro
# Processing Record 35 of Set 12 | smithers
# Processing Record 36 of Set 12 | marawi
# Processing Record 37 of Set 12 | qui nhon
# Processing Record 38 of Set 12 | melfort
# Processing Record 39 of Set 12 | prince albert
# Processing Record 40 of Set 12 | kvarkeno
# Processing Record 41 of Set 12 | xai-xai
# Processing Record 42 of Set 12 | redlands
# Processing Record 43 of Set 12 | basoko
# Processing Record 44 of Set 12 | plerin
# Processing Record 45 of Set 12 | lovington
# Processing Record 46 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 12 | ulaanbaatar
# Processing Record 48 of Set 12 | veraval
# Processing Record 49 of Set 12 | jalu
# Processing Record 50 of Set 12 | pokhara
# Processing Record 1 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 13 | kisangani
# Processing Record 3 of Set 13 | koungou
# Processing Record 4 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 5 of Set 13 | sola
# Processing Record 6 of Set 13 | kenora
# Processing Record 7 of Set 13 | palasbari
# Processing Record 8 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 13 | bundaberg
# Processing Record 11 of Set 13 | atar
# Processing Record 12 of Set 13 | palmer
# Processing Record 13 of Set 13 | tazmalt
# Processing Record 14 of Set 13 | green river
# Processing Record 15 of Set 13 | townsville
# Processing Record 16 of Set 13 | khani
# Processing Record 17 of Set 13 | arambagh
# Processing Record 18 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 13 | durban
# Processing Record 20 of Set 13 | skibbereen
# Processing Record 21 of Set 13 | wanning
# Processing Record 22 of Set 13 | maningrida
# Processing Record 23 of Set 13 | georgiyevka
# Processing Record 24 of Set 13 | vila franca do campo
# Processing Record 25 of Set 13 | uspenskaya
# Processing Record 26 of Set 13 | san luis
# Processing Record 27 of Set 13 | namibe
# Processing Record 28 of Set 13 | sisimiut
# Processing Record 29 of Set 13 | muros
# Processing Record 30 of Set 13 | guaratinga
# Processing Record 31 of Set 13 | tullow
# Processing Record 32 of Set 13 | pochutla
# Processing Record 33 of Set 13 | ramgarh
# Processing Record 34 of Set 13 | half moon bay
# Processing Record 35 of Set 13 | jam sahib
# Processing Record 36 of Set 13 | ambanja
# Processing Record 37 of Set 13 | thinadhoo
# Processing Record 38 of Set 13 | acajutla
# Processing Record 39 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 13 | puerto escondido
# Processing Record 41 of Set 13 | kruisfontein
# Processing Record 42 of Set 13 | yinchuan
# Processing Record 43 of Set 13 | tocopilla
# Processing Record 44 of Set 13 | sal rei
# Processing Record 45 of Set 13 | puerto gaitan
# Processing Record 46 of Set 13 | chengde
# Processing Record 47 of Set 13 | rio brilhante
# Processing Record 48 of Set 13 | dukat
# Processing Record 49 of Set 13 | nantucket
# Processing Record 50 of Set 13 | falavarjan
# Processing Record 1 of Set 14 | bremervorde
# Processing Record 2 of Set 14 | hurricane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 598

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kavaratti  10.5669   72.6420     81.63        73         100
# 1         Kirkwood  38.5834  -90.4068     47.52        37          20
# 2          Ushuaia -54.8000  -68.3000     51.42        61          40
# 3      East London -33.0153   27.9116     63.54        77           0
# 4      Port Alfred -33.5906   26.8910     61.48        62           9
# 5  Arraial Do Cabo -22.9661  -42.0278     91.36        69           0
# 6         Thompson  55.7435  -97.8558      3.36        85          20
# 7       Georgetown   5.4112  100.3354     76.95        94          20
# 8           Dikson  73.5069   80.5464    -17.55        95          50
# 9        Zutendaal  50.9325    5.5727     49.96        83          90
#
#    Wind Speed Country                 Date
# 0       12.46      IN  2021-11-18 17:22:02
# 1        7.00      US  2021-11-18 17:22:03
# 2       21.85      AR  2021-11-18 17:17:33
# 3       10.36      ZA  2021-11-18 17:18:15
# 4       11.59      ZA  2021-11-18 17:22:05
# 5       12.66      BR  2021-11-18 17:22:06
# 6        2.30      CA  2021-11-18 17:21:53
# 7        1.14      MY  2021-11-18 17:22:08
# 8        3.62      RU  2021-11-18 17:22:09
# 9       12.66      BE  2021-11-18 17:22:09

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0        Kavaratti      IN  2021-11-18 17:22:02  10.5669   72.6420     81.63
# 1         Kirkwood      US  2021-11-18 17:22:03  38.5834  -90.4068     47.52
# 2          Ushuaia      AR  2021-11-18 17:17:33 -54.8000  -68.3000     51.42
# 3      East London      ZA  2021-11-18 17:18:15 -33.0153   27.9116     63.54
# 4      Port Alfred      ZA  2021-11-18 17:22:05 -33.5906   26.8910     61.48
# 5  Arraial Do Cabo      BR  2021-11-18 17:22:06 -22.9661  -42.0278     91.36
# 6         Thompson      CA  2021-11-18 17:21:53  55.7435  -97.8558      3.36
# 7       Georgetown      MY  2021-11-18 17:22:08   5.4112  100.3354     76.95
# 8           Dikson      RU  2021-11-18 17:22:09  73.5069   80.5464    -17.55
# 9        Zutendaal      BE  2021-11-18 17:22:09  50.9325    5.5727     49.96
#
#    Humidity  Cloudiness  Wind Speed
# 0        73         100       12.46
# 1        37          20        7.00
# 2        61          40       21.85
# 3        77           0       10.36
# 4        62           9       11.59
# 5        69           0       12.66
# 6        85          20        2.30
# 7        94          20        1.14
# 8        95          50        3.62
# 9        83          90       12.66

# %%
# create the output file (CSV)
output_data_file = 'weather_data/cities.csv'

# export city data to csv
city_data_df.to_csv(output_data_file, index_label = 'City_ID')

# %%
# read csv file
file_to_load = 'weather_data/cities.csv'
city_data_df_2 = pd.read_csv(file_to_load)

# %%
# extract relevant fields form DF for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# get todays date in seconds
today = time.strftime('%x')
today
# Out:
# '11/18/21'

# %%
# build scatter plot to lat v max temp
plt.scatter(lats, max_temps,
           edgecolor='black',
           linewidths = 1,
           marker = 'o',
           alpha = 0.8,
           label = 'Cities')

plt.title('City Latitude vs. Max Temperature ' + time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylim()
plt.grid(True)

plt.savefig('weather_data/Fig1.png')

plt.show()

# %%
# build scatter plot to lat v humidity
plt.scatter(lats, humidity,
           edgecolor='black',
           linewidths = 1,
           marker = 'o',
           alpha = 0.8,
           label = 'Cities')

plt.title('City Latitude vs. Humidity(%) ' + time.strftime('%x'))
plt.ylabel('Humidity(%)')
plt.xlabel('Latitude')
plt.ylim()
plt.grid(True)

plt.savefig('weather_data/Fig2.png')

plt.show()

# %%
# build scatter plot to lat v cloudiness
plt.scatter(lats, cloudiness,
           edgecolor='black',
           linewidths = 1,
           marker = 'o',
           alpha = 0.8,
           label = 'Cities')

plt.title('City Latitude vs. Cloudiness(%) ' + time.strftime('%x'))
plt.ylabel('Cloudiness(%)')
plt.xlabel('Latitude')
plt.ylim()
plt.grid(True)

plt.savefig('weather_data/Fig3.png')

plt.show()

# %%
# build scatter plot to lat v wind speed
plt.scatter(lats, wind_speed,
           edgecolor='black',
           linewidths = 1,
           marker = 'o',
           alpha = 0.8,
           label = 'Cities')

plt.title('City Latitude vs. Wind Speed ' + time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylim()
plt.grid(True)

plt.savefig('weather_data/Fig4.png')

plt.show()

# %%
# create a function to create perform linear regression on the weather data 
#and plot a regression line and equation with data

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    #run the regression on hemisphere weather data 
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    #calculate the regression line 'y values' from the slope and intercept
    regress_values = x_values * slope + intercept 
    
    # get equation of the line
    line_eq = 'y = ' +str(round(slope,2)) + 'x + ' + str(round(intercept,2))
    
    # create a scatter plot and plot the regression line
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r')
    
    # annotate the text for the line equation 
    plt.annotate(line_eq, text_coordinates, fontsize = 15, color = 'r')
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df_2.loc[13]
index13
# Out:
# City_ID                        13
# City                      Litovko
# Country                        RU
# Date          2021-11-18 17:22:12
# Lat                       49.2361
# Lng                      135.1742
# Max Temp                    25.07
# Humidity                       97
# Cloudiness                    100
# Wind Speed                   3.62
# Name: 13, dtype: object

# %%
northern_hemi_df = city_data_df_2.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df_2.loc[(city_data_df['Lat'] <= 0)]

# %%
# linear regresssion on the nothern hemishphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# call the function 
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Nothern Hemisphere \n for Maximum Temperature', 'Max Temp', (10,-20))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp', (-30,45))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Nothern Hemisphere \n for % Humidity', '% Humidity', (45,20))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity', (-30,20))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Nothern Hemisphere \n for % Cloudiness', '% Cloudiness', (45,20))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness', (-55,20))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Nothern Hemisphere \n for Wind Speed', 'Wind Speed', (0,30))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed', (-25,25))
