# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# %%
# create a set of random lats and lngs combos
lats = np.random.uniform(-90,90,size =2000)
lngs = np.random.uniform(-180,180,size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

# id nearest city for each lat and lng 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if city is unique add to cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 743

# %%
# import API key
from config import weather_api_key

# %%
# create URL from Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an empty list to hold the weather date 
city_data = []

# print the beginning of the logging
print('Beginning Data Retrieval       ')
print('-------------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all cities in the list 
for i, city in enumerate(cities):
    
    # group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create endpoint URL with each city 
    city_url = url + '&q=' + city.replace(' ', '+')
    
    #log the URl, record and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # add 1 to record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description":city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | port hedland
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | kenai
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | katherine
# Processing Record 8 of Set 1 | avera
# Processing Record 9 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | maple creek
# Processing Record 12 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | bubaque
# Processing Record 15 of Set 1 | akhmim
# Processing Record 16 of Set 1 | tigil
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | porto novo
# Processing Record 20 of Set 1 | borodino
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | salalah
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | bukama
# Processing Record 31 of Set 1 | vestmannaeyjar
# Processing Record 32 of Set 1 | haines junction
# Processing Record 33 of Set 1 | chicama
# Processing Record 34 of Set 1 | portland
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | vao
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | steubenville
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | cayenne
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | gap
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | bundaberg
# Processing Record 2 of Set 2 | tortoli
# Processing Record 3 of Set 2 | port lincoln
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | nuuk
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | ambulu
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | maryville
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | axim
# Processing Record 19 of Set 2 | westport
# Processing Record 20 of Set 2 | kundiawa
# Processing Record 21 of Set 2 | san nicolas
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | polignano a mare
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | ukiah
# Processing Record 27 of Set 2 | dakoro
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | mountain home
# Processing Record 30 of Set 2 | nueva loja
# Processing Record 31 of Set 2 | port hardy
# Processing Record 32 of Set 2 | andenes
# Processing Record 33 of Set 2 | xinye
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | homer
# Processing Record 36 of Set 2 | jalu
# Processing Record 37 of Set 2 | sedro-woolley
# Processing Record 38 of Set 2 | agadir
# Processing Record 39 of Set 2 | shenjiamen
# Processing Record 40 of Set 2 | biak
# Processing Record 41 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 2 | hofn
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | marshall
# Processing Record 46 of Set 2 | kapit
# Processing Record 47 of Set 2 | nauta
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | narsaq
# Processing Record 50 of Set 2 | juba
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | alugan
# Processing Record 3 of Set 3 | sechura
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | castrovillari
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | camocim
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | belaya gora
# Processing Record 11 of Set 3 | oksfjord
# Processing Record 12 of Set 3 | klaksvik
# Processing Record 13 of Set 3 | victoria
# Processing Record 14 of Set 3 | hagere selam
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | xining
# Processing Record 17 of Set 3 | calais
# Processing Record 18 of Set 3 | joao pinheiro
# Processing Record 19 of Set 3 | rosarito
# Processing Record 20 of Set 3 | taraza
# Processing Record 21 of Set 3 | gat
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | griffith
# Processing Record 26 of Set 3 | bouar
# Processing Record 27 of Set 3 | turochak
# Processing Record 28 of Set 3 | port macquarie
# Processing Record 29 of Set 3 | hobart
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | zyryanka
# Processing Record 32 of Set 3 | burgeo
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | sawakin
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | udachnyy
# Processing Record 37 of Set 3 | lufilufi
# Processing Record 38 of Set 3 | laguna
# Processing Record 39 of Set 3 | baherden
# Processing Record 40 of Set 3 | kadyy
# Processing Record 41 of Set 3 | alyangula
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | silifke
# Processing Record 44 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 3 | durham
# Processing Record 46 of Set 3 | minna
# Processing Record 47 of Set 3 | alakurtti
# Processing Record 48 of Set 3 | camacha
# Processing Record 49 of Set 3 | balabac
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | tra vinh
# Processing Record 3 of Set 4 | biltine
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | goderich
# Processing Record 6 of Set 4 | surt
# Processing Record 7 of Set 4 | shingu
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | vagur
# Processing Record 11 of Set 4 | nanortalik
# Processing Record 12 of Set 4 | morondava
# Processing Record 13 of Set 4 | price
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | sorland
# Processing Record 16 of Set 4 | saint anthony
# Processing Record 17 of Set 4 | sanmenxia
# Processing Record 18 of Set 4 | pundaguitan
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | tezu
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | isiro
# Processing Record 23 of Set 4 | kytlym
# City not found. Skipping...
# Processing Record 24 of Set 4 | poya
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | neuquen
# Processing Record 27 of Set 4 | kenora
# Processing Record 28 of Set 4 | bathsheba
# Processing Record 29 of Set 4 | mackenzie
# Processing Record 30 of Set 4 | eydhafushi
# Processing Record 31 of Set 4 | deogarh
# Processing Record 32 of Set 4 | misratah
# Processing Record 33 of Set 4 | okhotsk
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | porto nacional
# Processing Record 37 of Set 4 | chapais
# Processing Record 38 of Set 4 | chippenham
# Processing Record 39 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 4 | changji
# Processing Record 41 of Set 4 | ixtapa
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | pimenta bueno
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | leningradskiy
# Processing Record 46 of Set 4 | le portel
# Processing Record 47 of Set 4 | jilmah
# City not found. Skipping...
# Processing Record 48 of Set 4 | samarai
# Processing Record 49 of Set 4 | tondano
# Processing Record 50 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 5 | puerto escondido
# Processing Record 2 of Set 5 | saryg-sep
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | faya
# Processing Record 5 of Set 5 | tateyama
# Processing Record 6 of Set 5 | springdale
# Processing Record 7 of Set 5 | kieta
# Processing Record 8 of Set 5 | foix
# Processing Record 9 of Set 5 | puerto vallarta
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | san patricio
# Processing Record 12 of Set 5 | marsa matruh
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | urumqi
# Processing Record 15 of Set 5 | muzhi
# Processing Record 16 of Set 5 | hami
# Processing Record 17 of Set 5 | bheramara
# Processing Record 18 of Set 5 | watertown
# Processing Record 19 of Set 5 | gambela
# Processing Record 20 of Set 5 | carutapera
# Processing Record 21 of Set 5 | kollam
# Processing Record 22 of Set 5 | joplin
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | san lawrenz
# Processing Record 25 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | svetlyy
# Processing Record 30 of Set 5 | taltal
# Processing Record 31 of Set 5 | mulchen
# Processing Record 32 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 5 | kiunga
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | manzanillo
# Processing Record 38 of Set 5 | saint-georges
# Processing Record 39 of Set 5 | waingapu
# Processing Record 40 of Set 5 | kulunda
# Processing Record 41 of Set 5 | beri
# Processing Record 42 of Set 5 | dandong
# Processing Record 43 of Set 5 | brigantine
# Processing Record 44 of Set 5 | lavrentiya
# Processing Record 45 of Set 5 | ostrovnoy
# Processing Record 46 of Set 5 | torbay
# Processing Record 47 of Set 5 | formosa
# Processing Record 48 of Set 5 | pitanga
# Processing Record 49 of Set 5 | dekar
# Processing Record 50 of Set 5 | storslett
# Processing Record 1 of Set 6 | hervey bay
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | carlsbad
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | sola
# Processing Record 7 of Set 6 | deputatskiy
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | pakwach
# City not found. Skipping...
# Processing Record 10 of Set 6 | asyut
# Processing Record 11 of Set 6 | caravelas
# Processing Record 12 of Set 6 | maragogi
# Processing Record 13 of Set 6 | katobu
# Processing Record 14 of Set 6 | souillac
# Processing Record 15 of Set 6 | mattru
# Processing Record 16 of Set 6 | touros
# Processing Record 17 of Set 6 | alamo
# Processing Record 18 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 6 | mahebourg
# Processing Record 20 of Set 6 | santiago
# Processing Record 21 of Set 6 | auki
# Processing Record 22 of Set 6 | flinders
# Processing Record 23 of Set 6 | svetlogorsk
# Processing Record 24 of Set 6 | joaima
# Processing Record 25 of Set 6 | luanda
# Processing Record 26 of Set 6 | magdalena
# Processing Record 27 of Set 6 | san jose
# Processing Record 28 of Set 6 | pervomayskoye
# Processing Record 29 of Set 6 | xichang
# Processing Record 30 of Set 6 | elko
# Processing Record 31 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 6 | sioux lookout
# Processing Record 33 of Set 6 | bengkulu
# Processing Record 34 of Set 6 | horta
# Processing Record 35 of Set 6 | fulitun
# City not found. Skipping...
# Processing Record 36 of Set 6 | adrar
# Processing Record 37 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 6 | esperance
# Processing Record 39 of Set 6 | honningsvag
# Processing Record 40 of Set 6 | uvat
# Processing Record 41 of Set 6 | cap malheureux
# Processing Record 42 of Set 6 | port-gentil
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | zhizdra
# Processing Record 45 of Set 6 | margate
# Processing Record 46 of Set 6 | abu samrah
# Processing Record 47 of Set 6 | lagoa
# Processing Record 48 of Set 6 | sicuani
# Processing Record 49 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 6 | san borja
# Processing Record 1 of Set 7 | supaul
# Processing Record 2 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 7 | hecun
# Processing Record 4 of Set 7 | fayaoue
# Processing Record 5 of Set 7 | norman wells
# Processing Record 6 of Set 7 | belmonte
# Processing Record 7 of Set 7 | kharhial
# Processing Record 8 of Set 7 | pali
# Processing Record 9 of Set 7 | san rafael
# Processing Record 10 of Set 7 | pacasmayo
# Processing Record 11 of Set 7 | praia da vitoria
# Processing Record 12 of Set 7 | sitka
# Processing Record 13 of Set 7 | qaanaaq
# Processing Record 14 of Set 7 | acapulco
# Processing Record 15 of Set 7 | ibaiti
# Processing Record 16 of Set 7 | yar
# Processing Record 17 of Set 7 | college
# Processing Record 18 of Set 7 | santiago del estero
# Processing Record 19 of Set 7 | sabang
# Processing Record 20 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 7 | ilulissat
# Processing Record 23 of Set 7 | hamilton
# Processing Record 24 of Set 7 | fairbanks
# Processing Record 25 of Set 7 | necochea
# Processing Record 26 of Set 7 | hailar
# Processing Record 27 of Set 7 | kavaratti
# Processing Record 28 of Set 7 | faanui
# Processing Record 29 of Set 7 | noumea
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | grindavik
# Processing Record 32 of Set 7 | arman
# Processing Record 33 of Set 7 | batagay-alyta
# Processing Record 34 of Set 7 | villazon
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | kupang
# Processing Record 37 of Set 7 | primore
# City not found. Skipping...
# Processing Record 38 of Set 7 | maceio
# Processing Record 39 of Set 7 | sampit
# Processing Record 40 of Set 7 | denpasar
# Processing Record 41 of Set 7 | hambantota
# Processing Record 42 of Set 7 | kodino
# Processing Record 43 of Set 7 | jacareacanga
# Processing Record 44 of Set 7 | cherskiy
# Processing Record 45 of Set 7 | ekhabi
# Processing Record 46 of Set 7 | mount gambier
# Processing Record 47 of Set 7 | fort frances
# Processing Record 48 of Set 7 | carlisle
# Processing Record 49 of Set 7 | bokovskaya
# Processing Record 50 of Set 7 | luwuk
# Processing Record 1 of Set 8 | kaduqli
# Processing Record 2 of Set 8 | kunya
# Processing Record 3 of Set 8 | yinchuan
# Processing Record 4 of Set 8 | aneho
# Processing Record 5 of Set 8 | pandan
# Processing Record 6 of Set 8 | port moresby
# Processing Record 7 of Set 8 | provideniya
# Processing Record 8 of Set 8 | palmer
# Processing Record 9 of Set 8 | te anau
# Processing Record 10 of Set 8 | abha
# Processing Record 11 of Set 8 | mapiripan
# Processing Record 12 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 8 | tuatapere
# Processing Record 14 of Set 8 | kaeo
# Processing Record 15 of Set 8 | srednekolymsk
# Processing Record 16 of Set 8 | kudat
# Processing Record 17 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 18 of Set 8 | mitsamiouli
# Processing Record 19 of Set 8 | kutum
# Processing Record 20 of Set 8 | aksarka
# Processing Record 21 of Set 8 | kuryk
# Processing Record 22 of Set 8 | taoudenni
# Processing Record 23 of Set 8 | port blair
# Processing Record 24 of Set 8 | muana
# Processing Record 25 of Set 8 | novoagansk
# Processing Record 26 of Set 8 | karratha
# Processing Record 27 of Set 8 | tiksi
# Processing Record 28 of Set 8 | ust-kulom
# Processing Record 29 of Set 8 | tam ky
# Processing Record 30 of Set 8 | acajutla
# Processing Record 31 of Set 8 | fukue
# Processing Record 32 of Set 8 | geraldton
# Processing Record 33 of Set 8 | setermoen
# Processing Record 34 of Set 8 | kampene
# Processing Record 35 of Set 8 | yenagoa
# Processing Record 36 of Set 8 | siutu
# City not found. Skipping...
# Processing Record 37 of Set 8 | voi
# Processing Record 38 of Set 8 | zelenoborsk
# Processing Record 39 of Set 8 | mackay
# Processing Record 40 of Set 8 | mindelo
# Processing Record 41 of Set 8 | tevriz
# Processing Record 42 of Set 8 | korla
# Processing Record 43 of Set 8 | belle fourche
# Processing Record 44 of Set 8 | fort dix
# Processing Record 45 of Set 8 | handwara
# City not found. Skipping...
# Processing Record 46 of Set 8 | penapolis
# Processing Record 47 of Set 8 | saint-francois
# Processing Record 48 of Set 8 | wa
# City not found. Skipping...
# Processing Record 49 of Set 8 | gamboma
# Processing Record 50 of Set 8 | lima
# Processing Record 1 of Set 9 | moratuwa
# Processing Record 2 of Set 9 | mwene-ditu
# Processing Record 3 of Set 9 | kunigal
# Processing Record 4 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 9 | santa rosalia
# Processing Record 6 of Set 9 | isla vista
# Processing Record 7 of Set 9 | berlevag
# Processing Record 8 of Set 9 | alice town
# Processing Record 9 of Set 9 | rudnyy
# Processing Record 10 of Set 9 | ballina
# Processing Record 11 of Set 9 | basco
# Processing Record 12 of Set 9 | menongue
# Processing Record 13 of Set 9 | rundu
# Processing Record 14 of Set 9 | atascadero
# Processing Record 15 of Set 9 | sinnamary
# Processing Record 16 of Set 9 | zhob
# Processing Record 17 of Set 9 | shawnee
# Processing Record 18 of Set 9 | ouegoa
# Processing Record 19 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 9 | cabo rojo
# Processing Record 21 of Set 9 | san juan
# Processing Record 22 of Set 9 | coquimbo
# Processing Record 23 of Set 9 | awjilah
# Processing Record 24 of Set 9 | grand gaube
# Processing Record 25 of Set 9 | kudahuvadhoo
# Processing Record 26 of Set 9 | nouadhibou
# Processing Record 27 of Set 9 | derbent
# Processing Record 28 of Set 9 | vila franca do campo
# Processing Record 29 of Set 9 | tomatlan
# Processing Record 30 of Set 9 | igarka
# Processing Record 31 of Set 9 | candido mendes
# Processing Record 32 of Set 9 | vanavara
# Processing Record 33 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 9 | calvinia
# Processing Record 35 of Set 9 | warwick
# Processing Record 36 of Set 9 | tiarei
# Processing Record 37 of Set 9 | melfort
# Processing Record 38 of Set 9 | pisco
# Processing Record 39 of Set 9 | soyo
# Processing Record 40 of Set 9 | mayo
# Processing Record 41 of Set 9 | poykovskiy
# Processing Record 42 of Set 9 | mozarlandia
# Processing Record 43 of Set 9 | ganta
# Processing Record 44 of Set 9 | vaitape
# Processing Record 45 of Set 9 | viedma
# Processing Record 46 of Set 9 | takoradi
# Processing Record 47 of Set 9 | santa maria da vitoria
# Processing Record 48 of Set 9 | vostok
# Processing Record 49 of Set 9 | ust-karsk
# Processing Record 50 of Set 9 | dawei
# Processing Record 1 of Set 10 | namatanai
# Processing Record 2 of Set 10 | gornyy
# Processing Record 3 of Set 10 | huilong
# Processing Record 4 of Set 10 | sao filipe
# Processing Record 5 of Set 10 | disna
# Processing Record 6 of Set 10 | koping
# Processing Record 7 of Set 10 | santa marta
# Processing Record 8 of Set 10 | arkhara
# Processing Record 9 of Set 10 | nemuro
# Processing Record 10 of Set 10 | cerete
# Processing Record 11 of Set 10 | manavalakurichi
# Processing Record 12 of Set 10 | tamiahua
# Processing Record 13 of Set 10 | sabha
# Processing Record 14 of Set 10 | bristol
# Processing Record 15 of Set 10 | urtaaul
# City not found. Skipping...
# Processing Record 16 of Set 10 | zhigansk
# Processing Record 17 of Set 10 | dunmore east
# Processing Record 18 of Set 10 | boa vista
# Processing Record 19 of Set 10 | kinwat
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | casper
# Processing Record 22 of Set 10 | roebourne
# Processing Record 23 of Set 10 | dashitou
# Processing Record 24 of Set 10 | notse
# Processing Record 25 of Set 10 | mahibadhoo
# Processing Record 26 of Set 10 | ferme-neuve
# Processing Record 27 of Set 10 | koslan
# Processing Record 28 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 10 | guilin
# Processing Record 30 of Set 10 | teknaf
# Processing Record 31 of Set 10 | kashan
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | berezovyy
# Processing Record 34 of Set 10 | fernie
# Processing Record 35 of Set 10 | puerto leguizamo
# Processing Record 36 of Set 10 | vanimo
# Processing Record 37 of Set 10 | tatawin
# Processing Record 38 of Set 10 | cockburn town
# Processing Record 39 of Set 10 | rocha
# Processing Record 40 of Set 10 | chitrakonda
# Processing Record 41 of Set 10 | santa cruz
# Processing Record 42 of Set 10 | san ramon
# Processing Record 43 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 10 | meadow lake
# Processing Record 45 of Set 10 | saint george
# Processing Record 46 of Set 10 | cairns
# Processing Record 47 of Set 10 | rangoon
# Processing Record 48 of Set 10 | mezhdurechensk
# Processing Record 49 of Set 10 | kokkola
# Processing Record 50 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 11 | kontagora
# Processing Record 2 of Set 11 | broken hill
# Processing Record 3 of Set 11 | dolinsk
# Processing Record 4 of Set 11 | tual
# Processing Record 5 of Set 11 | rio gallegos
# Processing Record 6 of Set 11 | nhamunda
# Processing Record 7 of Set 11 | honggang
# Processing Record 8 of Set 11 | tilichiki
# Processing Record 9 of Set 11 | catabangan
# Processing Record 10 of Set 11 | road town
# Processing Record 11 of Set 11 | port pirie
# Processing Record 12 of Set 11 | poronaysk
# Processing Record 13 of Set 11 | asau
# Processing Record 14 of Set 11 | cody
# Processing Record 15 of Set 11 | zatoka
# Processing Record 16 of Set 11 | dingle
# Processing Record 17 of Set 11 | amapa
# Processing Record 18 of Set 11 | chara
# Processing Record 19 of Set 11 | tete
# Processing Record 20 of Set 11 | novoleushkovskaya
# Processing Record 21 of Set 11 | muravlenko
# Processing Record 22 of Set 11 | onega
# Processing Record 23 of Set 11 | tabuk
# Processing Record 24 of Set 11 | daru
# Processing Record 25 of Set 11 | ahipara
# Processing Record 26 of Set 11 | puerto del rosario
# Processing Record 27 of Set 11 | ofaqim
# Processing Record 28 of Set 11 | togur
# Processing Record 29 of Set 11 | barabinsk
# Processing Record 30 of Set 11 | punta de bombon
# Processing Record 31 of Set 11 | glendive
# Processing Record 32 of Set 11 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 33 of Set 11 | zabol
# Processing Record 34 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 11 | vila velha
# Processing Record 36 of Set 11 | reichenau
# Processing Record 37 of Set 11 | naze
# Processing Record 38 of Set 11 | sandwick
# Processing Record 39 of Set 11 | freetown
# Processing Record 40 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 11 | turukhansk
# Processing Record 42 of Set 11 | innisfail
# Processing Record 43 of Set 11 | santa maria
# Processing Record 44 of Set 11 | san quintin
# Processing Record 45 of Set 11 | thunder bay
# Processing Record 46 of Set 11 | boyolangu
# Processing Record 47 of Set 11 | xam nua
# Processing Record 48 of Set 11 | bitkine
# Processing Record 49 of Set 11 | los llanos de aridane
# Processing Record 50 of Set 11 | tres arroyos
# Processing Record 1 of Set 12 | manaus
# Processing Record 2 of Set 12 | severnyy
# Processing Record 3 of Set 12 | buchanan
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | pokosnoye
# Processing Record 6 of Set 12 | san vicente
# Processing Record 7 of Set 12 | enumclaw
# Processing Record 8 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 12 | poum
# Processing Record 10 of Set 12 | ripoll
# Processing Record 11 of Set 12 | tublay
# Processing Record 12 of Set 12 | canberra
# Processing Record 13 of Set 12 | kochetok
# Processing Record 14 of Set 12 | port-cartier
# Processing Record 15 of Set 12 | narasannapeta
# Processing Record 16 of Set 12 | yumen
# Processing Record 17 of Set 12 | inhambane
# Processing Record 18 of Set 12 | wembley
# Processing Record 19 of Set 12 | teguldet
# Processing Record 20 of Set 12 | namibe
# Processing Record 21 of Set 12 | labuhan
# Processing Record 22 of Set 12 | gurupa
# Processing Record 23 of Set 12 | kalengwa
# Processing Record 24 of Set 12 | kahului
# Processing Record 25 of Set 12 | lingyuan
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | havre-saint-pierre
# Processing Record 28 of Set 12 | batemans bay
# Processing Record 29 of Set 12 | sur
# Processing Record 30 of Set 12 | beringovskiy
# Processing Record 31 of Set 12 | brufut
# Processing Record 32 of Set 12 | davila
# Processing Record 33 of Set 12 | cururupu
# Processing Record 34 of Set 12 | rusape
# Processing Record 35 of Set 12 | port keats
# Processing Record 36 of Set 12 | baykit
# Processing Record 37 of Set 12 | boddam
# Processing Record 38 of Set 12 | sakaiminato
# Processing Record 39 of Set 12 | caraballeda
# Processing Record 40 of Set 12 | algeciras
# Processing Record 41 of Set 12 | alofi
# Processing Record 42 of Set 12 | ketchikan
# Processing Record 43 of Set 12 | sisimiut
# Processing Record 44 of Set 12 | mamou
# Processing Record 45 of Set 12 | augusto correa
# Processing Record 46 of Set 12 | valparaiso
# Processing Record 47 of Set 12 | tazovskiy
# Processing Record 48 of Set 12 | paraiso
# Processing Record 49 of Set 12 | amalapuram
# Processing Record 50 of Set 12 | sohag
# Processing Record 1 of Set 13 | zapolyarnyy
# Processing Record 2 of Set 13 | rosita
# Processing Record 3 of Set 13 | la ronge
# Processing Record 4 of Set 13 | berikulskiy
# City not found. Skipping...
# Processing Record 5 of Set 13 | roald
# Processing Record 6 of Set 13 | lake city
# Processing Record 7 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 13 | garowe
# Processing Record 9 of Set 13 | nantucket
# Processing Record 10 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 11 of Set 13 | huanuco
# Processing Record 12 of Set 13 | lompoc
# Processing Record 13 of Set 13 | hualmay
# Processing Record 14 of Set 13 | kemi
# Processing Record 15 of Set 13 | gayny
# Processing Record 16 of Set 13 | qena
# Processing Record 17 of Set 13 | natal
# Processing Record 18 of Set 13 | komsomolskiy
# Processing Record 19 of Set 13 | aksum
# Processing Record 20 of Set 13 | henties bay
# Processing Record 21 of Set 13 | livingston
# Processing Record 22 of Set 13 | oistins
# Processing Record 23 of Set 13 | concordia
# Processing Record 24 of Set 13 | sao miguel do araguaia
# Processing Record 25 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 13 | ozernovskiy
# Processing Record 27 of Set 13 | venado tuerto
# Processing Record 28 of Set 13 | chatellerault
# Processing Record 29 of Set 13 | samana
# Processing Record 30 of Set 13 | dunedin
# Processing Record 31 of Set 13 | maniitsoq
# Processing Record 32 of Set 13 | synya
# Processing Record 33 of Set 13 | nelson bay
# Processing Record 34 of Set 13 | vikulovo
# Processing Record 35 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 36 of Set 13 | ahuimanu
# Processing Record 37 of Set 13 | ziarat
# Processing Record 38 of Set 13 | burns lake
# Processing Record 39 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 13 | tyumentsevo
# Processing Record 41 of Set 13 | high level
# Processing Record 42 of Set 13 | maracaju
# Processing Record 43 of Set 13 | nacala
# Processing Record 44 of Set 13 | okha
# Processing Record 45 of Set 13 | teya
# Processing Record 46 of Set 13 | itarema
# Processing Record 47 of Set 13 | yerakion
# Processing Record 48 of Set 13 | puebla
# Processing Record 49 of Set 13 | taiobeiras
# Processing Record 50 of Set 13 | jumla
# Processing Record 1 of Set 14 | alenquer
# Processing Record 2 of Set 14 | emerald
# Processing Record 3 of Set 14 | oume
# Processing Record 4 of Set 14 | stykkisholmur
# Processing Record 5 of Set 14 | yining
# Processing Record 6 of Set 14 | andrelandia
# Processing Record 7 of Set 14 | malanje
# Processing Record 8 of Set 14 | altay
# Processing Record 9 of Set 14 | baiao
# Processing Record 10 of Set 14 | rio grande
# Processing Record 11 of Set 14 | plymouth
# Processing Record 12 of Set 14 | agadez
# Processing Record 13 of Set 14 | san jeronimo
# Processing Record 14 of Set 14 | tabon
# Processing Record 15 of Set 14 | acarau
# Processing Record 16 of Set 14 | laurinburg
# Processing Record 17 of Set 14 | paranhos
# Processing Record 18 of Set 14 | marawi
# Processing Record 19 of Set 14 | iralaya
# Processing Record 20 of Set 14 | energeticheskiy
# Processing Record 21 of Set 14 | mayumba
# Processing Record 22 of Set 14 | gazni
# City not found. Skipping...
# Processing Record 23 of Set 14 | villa rica
# Processing Record 24 of Set 14 | sao joao da barra
# Processing Record 25 of Set 14 | kununurra
# Processing Record 26 of Set 14 | grande prairie
# Processing Record 27 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 14 | panaba
# Processing Record 29 of Set 14 | kamwenge
# Processing Record 30 of Set 14 | bonavista
# Processing Record 31 of Set 14 | nichinan
# Processing Record 32 of Set 14 | warrington
# Processing Record 33 of Set 14 | vegueta
# Processing Record 34 of Set 14 | balkhash
# Processing Record 35 of Set 14 | santa cruz cabralia
# Processing Record 36 of Set 14 | jiuquan
# Processing Record 37 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 38 of Set 14 | kez
# Processing Record 39 of Set 14 | shetpe
# Processing Record 40 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 14 | tuni
# Processing Record 42 of Set 14 | duku
# Processing Record 43 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 14 | dickson
# Processing Record 45 of Set 14 | araouane
# Processing Record 46 of Set 14 | farafangana
# Processing Record 47 of Set 14 | virginia beach
# Processing Record 48 of Set 14 | pierre
# Processing Record 49 of Set 14 | vostochnyy
# Processing Record 50 of Set 14 | kailua
# Processing Record 1 of Set 15 | cabedelo
# Processing Record 2 of Set 15 | muyezerskiy
# Processing Record 3 of Set 15 | santiago de chuco
# Processing Record 4 of Set 15 | adre
# Processing Record 5 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 15 | marigot
# Processing Record 7 of Set 15 | lebedyan
# Processing Record 8 of Set 15 | revda
# Processing Record 9 of Set 15 | san juan de los morros
# Processing Record 10 of Set 15 | nyurba
# Processing Record 11 of Set 15 | sarangani
# Processing Record 12 of Set 15 | matiri
# Processing Record 13 of Set 15 | mount darwin
# Processing Record 14 of Set 15 | loknya
# Processing Record 15 of Set 15 | marsh harbour
# Processing Record 16 of Set 15 | ngunut
# Processing Record 17 of Set 15 | agbor
# Processing Record 18 of Set 15 | barkhan
# Processing Record 19 of Set 15 | kidal
# Processing Record 20 of Set 15 | coihaique
# Processing Record 21 of Set 15 | buluang
# Processing Record 22 of Set 15 | katangli
# Processing Record 23 of Set 15 | kurilsk
# Processing Record 24 of Set 15 | matamoros
# Processing Record 25 of Set 15 | soure
# Processing Record 26 of Set 15 | the valley
# Processing Record 27 of Set 15 | celestun
# Processing Record 28 of Set 15 | egvekinot
# Processing Record 29 of Set 15 | ambon
# Processing Record 30 of Set 15 | rypefjord
# Processing Record 31 of Set 15 | rodrigues alves
# Processing Record 32 of Set 15 | broome
# Processing Record 33 of Set 15 | verkhnyaya inta
# Processing Record 34 of Set 15 | doiwala
# Processing Record 35 of Set 15 | twin falls
# Processing Record 36 of Set 15 | canavieiras
# Processing Record 37 of Set 15 | kirkwall
# Processing Record 38 of Set 15 | burnie
# Processing Record 39 of Set 15 | voyvozh
# Processing Record 40 of Set 15 | nara
# Processing Record 41 of Set 15 | kamalasai
# Processing Record 42 of Set 15 | morro bay
# Processing Record 43 of Set 15 | corn island
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro -24.7911  -50.0119     76.06        47           5
# 1  Port Hedland -20.3167  118.5667     82.45        42         100
# 2   Tuktoyaktuk  69.4541 -133.0374    -16.60        76           1
# 3         Kenai  60.5544 -151.2583     -2.15        78          40
# 4        Avarua -21.2078 -159.7750     80.65        74          75
#
#    Wind Speed Weather Description Country                 Date
# 0        5.23           clear sky      BR  2021-11-21 20:02:58
# 1       10.36     overcast clouds      AU  2021-11-21 20:02:58
# 2        2.30           clear sky      CA  2021-11-21 19:58:02
# 3        3.44    scattered clouds      US  2021-11-21 20:02:59
# 4        5.75       broken clouds      CK  2021-11-21 19:58:11

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']
city_data_df = city_data_df[new_column_order]
city_data_df['Current Description'] = city_data_df['Weather Description'] 
del city_data_df['Weather Description']
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro      BR -24.7911  -50.0119     76.06        47           5
# 1  Port Hedland      AU -20.3167  118.5667     82.45        42         100
# 2   Tuktoyaktuk      CA  69.4541 -133.0374    -16.60        76           1
# 3         Kenai      US  60.5544 -151.2583     -2.15        78          40
# 4        Avarua      CK -21.2078 -159.7750     80.65        74          75
#
#    Wind Speed Current Description
# 0        5.23           clear sky
# 1       10.36     overcast clouds
# 2        2.30           clear sky
# 3        3.44    scattered clouds
# 4        5.75       broken clouds

# %%
output_data_file = 'Weather_Database/WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label = 'City_ID')
